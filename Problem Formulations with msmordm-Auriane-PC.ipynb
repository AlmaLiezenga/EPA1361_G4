# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

# %% [markdown]
# # Step 1: Problem formulation

# %%
# make sure pandas is version 1.0 or higher
# make sure networkx is verion 2.4 or higher
print(pd.__version__)
print(nx.__version__)
# Out:
# 1.2.3
# 2.5

# %%
from ema_workbench import (Model, CategoricalParameter,
                           ScalarOutcome, IntegerParameter, RealParameter)
from dike_model_function import DikeNetwork  # @UnresolvedImport


def sum_over(*args):
    return sum(args)
# Out:
# C:\Users\Auriane\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\optimization.py:48: ImportWarning: platypus based optimization not available
#   warnings.warn("platypus based optimization not available", ImportWarning)

# %%
from ema_workbench import (Model, MultiprocessingEvaluator, Policy, Scenario)

from ema_workbench.em_framework.evaluators import perform_experiments
from ema_workbench.em_framework.samplers import sample_uncertainties
from ema_workbench.util import ema_logging
import time
from problem_formulation import get_model_for_problem_formulation


ema_logging.log_to_stderr(ema_logging.INFO)

#choose problem formulation number, between 0-5
#each problem formulation has its own list of outcomes
dike_model, planning_steps = get_model_for_problem_formulation(6)
# Out:
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:18: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   df = pd.read_excel('./data/dikeIjssel.xlsx', dtype=object)
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:36: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   header=None, index_col=0).transpose()
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:38: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   index_col=0)
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:44: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   names=['project name', 0,1,2,3,4])
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:55: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   G.add_node('EWS', **pd.read_excel('./data/EWS.xlsx').to_dict())
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:60: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   index_col=0)
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\funs_generate_network.py:81: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   G.nodes[dike]['table'] = pd.read_excel(name, index_col=0).values
# C:\Users\Auriane\OneDrive\Q4\MBDM\final assignment\dike_model_function.py:36: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#   self.A = pd.read_excel('./data/hydrology/werklijn_params.xlsx')

# %%
#enlisting uncertainties, their types (RealParameter/IntegerParameter/CategoricalParameter), lower boundary, and upper boundary
for unc in dike_model.uncertainties:
    print(repr(unc))
    
uncertainties = dike_model.uncertainties

import copy
uncertainties = copy.deepcopy(dike_model.uncertainties)
# Out:
# CategoricalParameter('discount rate 0', [0, 1, 2, 3])
# CategoricalParameter('discount rate 1', [0, 1, 2, 3])
# CategoricalParameter('discount rate 2', [0, 1, 2, 3])
# IntegerParameter('A.0_ID flood wave shape', 0, 132)
# RealParameter('A.1_Bmax', 30, 350)
# RealParameter('A.1_pfail', 0, 1)
# CategoricalParameter('A.1_Brate', [0, 1, 2])
# RealParameter('A.2_Bmax', 30, 350)
# RealParameter('A.2_pfail', 0, 1)
# CategoricalParameter('A.2_Brate', [0, 1, 2])
# RealParameter('A.3_Bmax', 30, 350)
# RealParameter('A.3_pfail', 0, 1)
# CategoricalParameter('A.3_Brate', [0, 1, 2])
# RealParameter('A.4_Bmax', 30, 350)
# RealParameter('A.4_pfail', 0, 1)
# CategoricalParameter('A.4_Brate', [0, 1, 2])
# RealParameter('A.5_Bmax', 30, 350)
# RealParameter('A.5_pfail', 0, 1)
# CategoricalParameter('A.5_Brate', [0, 1, 2])

# %%
#enlisting policy levers, their types (RealParameter/IntegerParameter), lower boundary, and upper boundary
for policy in dike_model.levers:
    print(repr(policy))
    
levers = dike_model.levers 

import copy
levers = copy.deepcopy(dike_model.levers)
# Out:
# IntegerParameter('0_RfR 0', 0, 1)
# IntegerParameter('0_RfR 1', 0, 1)
# IntegerParameter('0_RfR 2', 0, 1)
# IntegerParameter('1_RfR 0', 0, 1)
# IntegerParameter('1_RfR 1', 0, 1)
# IntegerParameter('1_RfR 2', 0, 1)
# IntegerParameter('2_RfR 0', 0, 1)
# IntegerParameter('2_RfR 1', 0, 1)
# IntegerParameter('2_RfR 2', 0, 1)
# IntegerParameter('3_RfR 0', 0, 1)
# IntegerParameter('3_RfR 1', 0, 1)
# IntegerParameter('3_RfR 2', 0, 1)
# IntegerParameter('4_RfR 0', 0, 1)
# IntegerParameter('4_RfR 1', 0, 1)
# IntegerParameter('4_RfR 2', 0, 1)
# IntegerParameter('EWS_DaysToThreat', 0, 4)
# IntegerParameter('A.1_DikeIncrease 0', 0, 10)
# IntegerParameter('A.1_DikeIncrease 1', 0, 10)
# IntegerParameter('A.1_DikeIncrease 2', 0, 10)
# IntegerParameter('A.2_DikeIncrease 0', 0, 10)
# IntegerParameter('A.2_DikeIncrease 1', 0, 10)
# IntegerParameter('A.2_DikeIncrease 2', 0, 10)
# IntegerParameter('A.3_DikeIncrease 0', 0, 10)
# IntegerParameter('A.3_DikeIncrease 1', 0, 10)
# IntegerParameter('A.3_DikeIncrease 2', 0, 10)
# IntegerParameter('A.4_DikeIncrease 0', 0, 10)
# IntegerParameter('A.4_DikeIncrease 1', 0, 10)
# IntegerParameter('A.4_DikeIncrease 2', 0, 10)
# IntegerParameter('A.5_DikeIncrease 0', 0, 10)
# IntegerParameter('A.5_DikeIncrease 1', 0, 10)
# IntegerParameter('A.5_DikeIncrease 2', 0, 10)

# %%
#enlisting outcomes
for outcome in dike_model.outcomes:
    print(repr(outcome))
# Out:
# ScalarOutcome('A.1_Dike Investment Costs', variable_name=['A.1_Dike Investment Costs 0', 'A.1_Dike Investment Costs 1', 'A.1_Dike Investment Costs 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.1_Expected Annual Damage', variable_name=['A.1_Expected Annual Damage 0', 'A.1_Expected Annual Damage 1', 'A.1_Expected Annual Damage 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.1_Expected Number of Deaths', variable_name=['A.1_Expected Number of Deaths 0', 'A.1_Expected Number of Deaths 1', 'A.1_Expected Number of Deaths 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.2_Dike Investment Costs', variable_name=['A.2_Dike Investment Costs 0', 'A.2_Dike Investment Costs 1', 'A.2_Dike Investment Costs 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.2_Expected Annual Damage', variable_name=['A.2_Expected Annual Damage 0', 'A.2_Expected Annual Damage 1', 'A.2_Expected Annual Damage 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.2_Expected Number of Deaths', variable_name=['A.2_Expected Number of Deaths 0', 'A.2_Expected Number of Deaths 1', 'A.2_Expected Number of Deaths 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.3_Dike Investment Costs', variable_name=['A.3_Dike Investment Costs 0', 'A.3_Dike Investment Costs 1', 'A.3_Dike Investment Costs 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.3_Expected Annual Damage', variable_name=['A.3_Expected Annual Damage 0', 'A.3_Expected Annual Damage 1', 'A.3_Expected Annual Damage 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.3_Expected Number of Deaths', variable_name=['A.3_Expected Number of Deaths 0', 'A.3_Expected Number of Deaths 1', 'A.3_Expected Number of Deaths 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.4_Dike Investment Costs', variable_name=['A.4_Dike Investment Costs 0', 'A.4_Dike Investment Costs 1', 'A.4_Dike Investment Costs 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.4_Expected Annual Damage', variable_name=['A.4_Expected Annual Damage 0', 'A.4_Expected Annual Damage 1', 'A.4_Expected Annual Damage 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.4_Expected Number of Deaths', variable_name=['A.4_Expected Number of Deaths 0', 'A.4_Expected Number of Deaths 1', 'A.4_Expected Number of Deaths 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.5_Dike Investment Costs', variable_name=['A.5_Dike Investment Costs 0', 'A.5_Dike Investment Costs 1', 'A.5_Dike Investment Costs 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.5_Expected Annual Damage', variable_name=['A.5_Expected Annual Damage 0', 'A.5_Expected Annual Damage 1', 'A.5_Expected Annual Damage 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('A.5_Expected Number of Deaths', variable_name=['A.5_Expected Number of Deaths 0', 'A.5_Expected Number of Deaths 1', 'A.5_Expected Number of Deaths 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('RfR Total Costs', variable_name=['RfR Total Costs 0', 'RfR Total Costs 1', 'RfR Total Costs 2'], function=<function sum_over at 0x00000000053020D8>)
# ScalarOutcome('Expected Evacuation Costs', variable_name=['Expected Evacuation Costs 0', 'Expected Evacuation Costs 1', 'Expected Evacuation Costs 2'], function=<function sum_over at 0x00000000053020D8>)

# %% [raw]
# dike_model.outcomes = [ScalarOutcome('A.3_Dike Investment Costs', kind = ScalarOutcome.MINIMIZE, variable_name=['A.3_Dike Investment Costs 0', 'A.3_Dike Investment Costs 1', 'A.3_Dike Investment Costs 2'], function=<function sum_over at 0x0000024783D1E4C0>),
#                        ScalarOutcome('A.3_Expected Annual Damage', kind = ScalarOutcome.MINIMIZE, variable_name=['A.3_Expected Annual Damage 0', 'A.3_Expected Annual Damage 1', 'A.3_Expected Annual Damage 2'], function=<function sum_over at 0x0000024783D1E4C0>),
#                        ScalarOutcome('A.3_Expected Number of Deaths', kind = ScalarOutcome.MINIMIZE variable_name=['A.3_Expected Number of Deaths 0', 'A.3_Expected Number of Deaths 1', 'A.3_Expected Number of Deaths 2'], function=<function sum_over at 0x0000024783D1E4C0>),
#                        ScalarOutcome('Expected Evacuation Costs', variable_name=['Expected Evacuation Costs 0', 'Expected Evacuation Costs 1', 'Expected Evacuation Costs 2'], function=<function sum_over at 0x0000024783D1E4C0>)]

# %% [markdown]
# # Step 2: Searching for candidate solutions

# %%
#running the model through EMA workbench
from ema_workbench import (MultiprocessingEvaluator, ema_logging,
                           perform_experiments, SequentialEvaluator)
ema_logging.log_to_stderr(ema_logging.INFO)
 
#results = evaluator.perform_experiments(scenarios=500, policies=4)

with MultiprocessingEvaluator(dike_model) as evaluator:
    results1 = evaluator.optimize(nfe = 5e3, searchover='levers',
                                 epsilons=[0.1,]*len(dike_model.outcomes))
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] terminating pool
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-16b5561d0df0> in <module>
#       8 with MultiprocessingEvaluator(dike_model) as evaluator:
#       9     results1 = evaluator.optimize(nfe = 5e3, searchover='levers',
# ---> 10                                  epsilons=[0.1,]*len(dike_model.outcomes))
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\evaluators.py in optimize(self, algorithm, nfe, searchover, reference, constraints, convergence_freq, logging_freq, **kwargs)
#     188                         reference=reference, constraints=constraints,
#     189                         convergence_freq=convergence_freq,
# --> 190                         logging_freq=logging_freq, **kwargs)
#     191
#     192     def robust_optimize(self, robustness_functions, scenarios,
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\evaluators.py in optimize(models, algorithm, nfe, searchover, evaluator, reference, convergence, constraints, convergence_freq, logging_freq, **kwargs)
#     529
#     530     problem = to_problem(models, searchover, constraints=constraints,
# --> 531                          reference=reference)
#     532
#     533     # solve the optimization problem
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\optimization.py in to_problem(model, searchover, reference, constraints)
#     166     problem = Problem(searchover, decision_variables,
#     167                       outcome_names, constraints, reference=reference)
# --> 168     problem.types = to_platypus_types(decision_variables)
#     169     problem.directions = [outcome.kind for outcome in outcomes]
#     170     problem.constraints[:] = "==0"
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\optimization.py in to_platypus_types(decision_variables)
#     220     platypus parameter types'''
#     221     # TODO:: should categorical not be platypus.Subset, with size == 1?
# --> 222     _type_mapping = {RealParameter: platypus.Real,
#     223                      IntegerParameter: platypus.Integer,
#     224                      CategoricalParameter: platypus.Subset,
#
# AttributeError: 'NoneType' object has no attribute 'Real'

# %%
#observing the simulation runs
experiments, outcomes = results
print(outcomes.keys())
experiments
# Out:
# dict_keys(['A.1_Dike Investment Costs', 'A.1_Expected Annual Damage', 'A.1_Expected Number of Deaths', 'A.2_Dike Investment Costs', 'A.2_Expected Annual Damage', 'A.2_Expected Number of Deaths', 'A.3_Dike Investment Costs', 'A.3_Expected Annual Damage', 'A.3_Expected Number of Deaths', 'A.4_Dike Investment Costs', 'A.4_Expected Annual Damage', 'A.4_Expected Number of Deaths', 'A.5_Dike Investment Costs', 'A.5_Expected Annual Damage', 'A.5_Expected Number of Deaths', 'RfR Total Costs', 'Expected Evacuation Costs'])
#      A.0_ID flood wave shape    A.1_Bmax A.1_Brate  A.1_pfail    A.2_Bmax  \
# 0                      105.0  140.940690       1.5   0.041896  104.173925
# 1                       63.0  184.585782       1.5   0.985992  214.494521
# 2                      102.0  240.289952       1.0   0.519728  222.783284
# 3                      110.0  179.434775        10   0.918793   40.612236
# 4                      121.0  247.411200       1.5   0.071877  143.381703
# ..                       ...         ...       ...        ...         ...
# 195                      1.0  315.344668       1.5   0.924074  110.524082
# 196                     32.0   32.613705        10   0.129180  153.693385
# 197                     29.0  221.610810       1.0   0.269725  220.113178
# 198                     55.0  301.269204       1.0   0.337189  347.879256
# 199                     98.0  196.712347       1.0   0.561600  273.522808
#
#     A.2_Brate  A.2_pfail    A.3_Bmax A.3_Brate  A.3_pfail  ...  \
# 0         1.5   0.831531  147.238447        10   0.165693  ...
# 1         1.5   0.522683  322.129552       1.5   0.027378  ...
# 2         1.0   0.444285   94.213527        10   0.895861  ...
# 3         1.5   0.016694  153.626370        10   0.456306  ...
# 4         1.0   0.295884  301.534073       1.5   0.338974  ...
# ..        ...        ...         ...       ...        ...  ...
# 195       1.0   0.138316  114.260668       1.0   0.211933  ...
# 196        10   0.272433   55.002913        10   0.294248  ...
# 197       1.0   0.173459  102.703747       1.0   0.524897  ...
# 198       1.5   0.311372  172.659671       1.0   0.469724  ...
# 199       1.5   0.335494  338.055966       1.5   0.571968  ...
#
#      A.4_DikeIncrease 0 A.4_DikeIncrease 1  A.4_DikeIncrease 2  \
# 0                  10.0                2.0                 4.0
# 1                  10.0                2.0                 4.0
# 2                  10.0                2.0                 4.0
# 3                  10.0                2.0                 4.0
# 4                  10.0                2.0                 4.0
# ..                  ...                ...                 ...
# 195                 0.0                5.0                 9.0
# 196                 0.0                5.0                 9.0
# 197                 0.0                5.0                 9.0
# 198                 0.0                5.0                 9.0
# 199                 0.0                5.0                 9.0
#
#      A.5_DikeIncrease 0 A.5_DikeIncrease 1  A.5_DikeIncrease 2  \
# 0                   3.0                2.0                10.0
# 1                   3.0                2.0                10.0
# 2                   3.0                2.0                10.0
# 3                   3.0                2.0                10.0
# 4                   3.0                2.0                10.0
# ..                  ...                ...                 ...
# 195                 7.0                5.0                 7.0
# 196                 7.0                5.0                 7.0
# 197                 7.0                5.0                 7.0
# 198                 7.0                5.0                 7.0
# 199                 7.0                5.0                 7.0
#
#     EWS_DaysToThreat scenario policy     model
# 0                3.0      100      8  dikesnet
# 1                3.0      101      8  dikesnet
# 2                3.0      102      8  dikesnet
# 3                3.0      103      8  dikesnet
# 4                3.0      104      8  dikesnet
# ..               ...      ...    ...       ...
# 195              0.0      145     11  dikesnet
# 196              0.0      146     11  dikesnet
# 197              0.0      147     11  dikesnet
# 198              0.0      148     11  dikesnet
# 199              0.0      149     11  dikesnet
#
# [200 rows x 53 columns]

# %%
#defining specific policies
#for example, policy 1 is about extra protection in upper boundary
#policy 2 is about extra protection in lower boundary
#policy 3 is extra protection in random locations
from ema_workbench import Policy

policies = [Policy('policy 1', **{'0_RfR 0':1,
                                  '0_RfR 1':1,
                                  '0_RfR 2':1,
                                  'A.1_DikeIncrease 0':5}),
           Policy('policy 2', **{'4_RfR 0':1,
                                  '4_RfR 1':1,
                                  '4_RfR 2':1,
                                  'A.5_DikeIncrease 0':5}),
           Policy('policy 3', **{'1_RfR 0':1,
                                  '2_RfR 1':1,
                                  '3_RfR 2':1,
                                  'A.3_DikeIncrease 0':5})]

# %%
#pass the policies list to EMA workbench experiment runs
n_scenarios = 100
with MultiprocessingEvaluator(dike_model) as evaluator:
    results = evaluator.perform_experiments(n_scenarios,
                                            policies)
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] performing 100 scenarios * 3 policies * 1 model(s) = 300 experiments
# [MainProcess/INFO] 30 cases completed
# [MainProcess/INFO] 60 cases completed
# [MainProcess/INFO] 90 cases completed
# [MainProcess/INFO] 120 cases completed
# [MainProcess/INFO] 150 cases completed
# [MainProcess/INFO] 180 cases completed
# [MainProcess/INFO] 210 cases completed
# [MainProcess/INFO] 240 cases completed
# [MainProcess/INFO] 270 cases completed
# [MainProcess/INFO] 300 cases completed
# [MainProcess/INFO] experiments finished
# [MainProcess/INFO] terminating pool

# %%
#try to optimize(this will take forever)
from ema_workbench import MultiprocessingEvaluator, ema_logging
from ema_workbench.em_framework.evaluators import BaseEvaluator

ema_logging.log_to_stderr(ema_logging.INFO)
nfenr = 500#5e3
with MultiprocessingEvaluator(dike_model) as evaluator:
    results1 = evaluator.optimize(nfe=nfenr, searchover='levers',
                                 epsilons=[0.0000000000001,]*len(dike_model.outcomes))
# Out:
# [MainProcess/INFO] pool started
# [MainProcess/INFO] terminating pool
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-36a91abf412d> in <module>
#       7 with MultiprocessingEvaluator(dike_model) as evaluator:
#       8     results1 = evaluator.optimize(nfe=nfenr, searchover='levers',
# ----> 9                                  epsilons=[0.0000000000001,]*len(dike_model.outcomes))
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\evaluators.py in optimize(self, algorithm, nfe, searchover, reference, constraints, convergence_freq, logging_freq, **kwargs)
#     188                         reference=reference, constraints=constraints,
#     189                         convergence_freq=convergence_freq,
# --> 190                         logging_freq=logging_freq, **kwargs)
#     191
#     192     def robust_optimize(self, robustness_functions, scenarios,
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\evaluators.py in optimize(models, algorithm, nfe, searchover, evaluator, reference, convergence, constraints, convergence_freq, logging_freq, **kwargs)
#     529
#     530     problem = to_problem(models, searchover, constraints=constraints,
# --> 531                          reference=reference)
#     532
#     533     # solve the optimization problem
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\optimization.py in to_problem(model, searchover, reference, constraints)
#     166     problem = Problem(searchover, decision_variables,
#     167                       outcome_names, constraints, reference=reference)
# --> 168     problem.types = to_platypus_types(decision_variables)
#     169     problem.directions = [outcome.kind for outcome in outcomes]
#     170     problem.constraints[:] = "==0"
#
# ~\miniconda3\envs\gds\lib\site-packages\ema_workbench\em_framework\optimization.py in to_platypus_types(decision_variables)
#     220     platypus parameter types'''
#     221     # TODO:: should categorical not be platypus.Subset, with size == 1?
# --> 222     _type_mapping = {RealParameter: platypus.Real,
#     223                      IntegerParameter: platypus.Integer,
#     224                      CategoricalParameter: platypus.Subset,
#
# AttributeError: 'NoneType' object has no attribute 'Real'

# %%
results1

# %%
import matplotlib.pyplot as plt
from ema_workbench.analysis import parcoords

data = results1.loc[:, [o.name for o in dike_model.outcomes]]
limits = parcoords.get_limits(data)
limits.loc[0, ['Α.3_Expected Annual Damage', 'A.3_Expected Number of Deaths', 'Expected Evacuation Costs']] = 0

paraxes = parcoords.ParallelAxes(limits)
paraxes.plot(data)
#paraxes.invert_axis('max_P')
plt.show()
